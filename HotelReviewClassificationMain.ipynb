# %% [markdown]
# # Hotel Review Classification

# %% [markdown]
# This is a sample dataset which consists of 20,000 reviews and ratings for different hotels and our goal is to examine how travelers are communicating their positive and negative experiences in online platforms for staying in a specific hotel and major objective is what are the attributes that travelers are considering while selecting a hotel. With this manager can understand which elements of their hotel influence more in forming a positive review or improves hotel brand image.

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import string
import spacy
from spacy import displacy
import nltk
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import re
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Dense, SpatialDropout1D, Flatten, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPool1D, Dense
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from keras.models import load_model
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score, confusion_matrix, classification_report

# %%
nlp = spacy.load('en_core_web_lg')

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sailo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
hotel = pd.read_excel('hotel_reviews.xlsx')

# %%
hotel.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 320.3+ KB

# %% [markdown]
# ## Null Check

# %%
hotel.isna().sum()
# Out:
# Review    0
# Rating    0
# dtype: int64

# %% [markdown]
# ## Spaces Check

# %%
blanks = []

for i, rv, rt in hotel.itertuples():
    if rv.isspace():
        blanks.append(i)

# %%
blanks
# Out:
# []

# %%
hotel['Rating'].value_counts()
# Out:
# Rating
# 5    9054
# 4    6039
# 3    2184
# 2    1793
# 1    1421
# Name: count, dtype: int64

# %% [markdown]
# ## Categorical Conversion

# %%
hotel['Rating'] = pd.Categorical(hotel['Rating'])

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  category
# dtypes: category(1), object(1)
# memory usage: 180.4+ KB

# %% [markdown]
# ## Visualizing POS

# %%
displacy.render(nlp(hotel['Review'][1]), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ok nothing special charge diamond member
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  decided chain shot
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  anniversary
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , start booked suite paid extra website description not, suite bedroom bathroom standard hotel room, took printed reservation desk showed said things like tv couch ect desk clerk told oh mixed suites description
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kimpton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  website sorry free breakfast, got kidding, embassy suits sitting room bathroom bedroom unlike
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kimpton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  calls suite,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  stay offer correct false advertising, send
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kimpton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  preferred guest website email asking failure provide suite advertised website reservation description furnished hard copy reservation printout website desk manager duty did not reply solution, send email trip guest survey did not follow email mail, guess tell concerned guest.the staff ranged indifferent not helpful, asked desk good breakfast spots neighborhood hood told no hotels, gee best breakfast spots seattle
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  block away convenient hotel does not know exist, arrived
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late night 11 pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  inside run bellman busy chating cell phone help bags.prior arrival emailed hotel inform
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th anniversary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  half really picky wanted make sure good, got nice email saying like deliver bottle champagne chocolate covered strawberries room arrival celebrate, told needed foam pillows, arrival no champagne strawberries no foam pillows great room view alley high rise building good not better housekeeping staff cleaner room property, impressed left
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  shopping room got short trips
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , beds comfortable.not good ac-heat control
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 x 4 inch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  screen bring green shine directly eyes night, light sensitive tape controls.this not
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  start hotel clean business hotel super high rates, better chain hotels seattle,  </div></span>

# %%
def word_cleaner(text):
    
    text = text.strip()
    
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    text = re.sub(r'[^\x00-\x7F]+', '', text)

    doc = nlp(text)

    lemmatized_words = [token.lemma_ for token in doc]
    
    additional_stopwords = set(['hotel', 'resort', 'day', 'use', 'need', 'think', 'night', 'say', 'look', 'beach', 'stay', 'time', 'people', 'place', 'area', 'room', 'come', 'staff', 'tell'])

    stop_words = set(stopwords.words('english')).union(set(spacy.lang.en.stop_words.STOP_WORDS)).union(additional_stopwords) - {'not'}
    
    lemmatized_words = [word for word in lemmatized_words if word.lower() not in stop_words]

    cleaned_text = ' '.join(lemmatized_words)

    return cleaned_text

# %% [markdown]
# Executed the below code cell, Since SpaCy was used for lemmatization it was taking time and hence dumped the dataframe to another excel

# %%
# hotel['cleaned_reviews'] = hotel['Review'].apply(word_cleaner)
# hotel.to_excel('cleaned_hotel.xlsx')

# %%
hotel = pd.read_excel('cleaned_hotel.xlsx')

# %%
displacy.render(nlp(hotel['cleaned_reviews'][1]), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ok special charge diamond member
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  decide chain shoot
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  anniversary
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  start book suite pay extra website description not suite bedroom bathroom standard print reservation desk thing like tv couch ect desk clerk oh mixed suite description kimpton website sorry free breakfast kid embassy suit sit bathroom bedroom unlike
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kimpton suite 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  offer correct false advertising send
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kimpton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  preferred guest website email ask failure provide suite advertise website reservation description furnish hard copy reservation printout website desk manager duty not reply solution send email trip guest survey not follow email mail guess concerned guestthe range indifferent not helpful ask desk good breakfast spot neighborhood hood gee good breakfast spot seattle
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  block away convenient not know exist arrive
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late 11 pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  inside run
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bellman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  busy chat cell phone help
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bagsprior
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  arrival email inform
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th anniversary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  picky want sure good nice email like deliver bottle champagne chocolate cover strawberry arrival celebrate foam pillow arrival champagne strawberry foam pillow great view alley high rise build good not housekeeping clean property impress leave
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  shopping short trip
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  bed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     comfortablenot good acheat control
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 x 4 inch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  screen bring green shine directly eye light sensitive tape controlsthis not
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  start clean business super high rate chain seattle</div></span>

# %%
displacy.render(nlp(hotel['cleaned_reviews'][1]), style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="28332f98ab974dfc855ef777b9e4e610-0" class="displacy" width="36275" height="1362.0" direction="ltr" style="max-width: none; height: 1362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ok</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">special</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">charge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">diamond</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">member</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">hilton</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">decide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">chain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">shoot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">20th</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">anniversary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">seattle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">start</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">book</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">suite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">pay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">extra</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">website</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">description</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">suite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">bedroom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">bathroom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">standard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">print</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">reservation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">desk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">thing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">tv</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">co

# %%
vectorizer = CountVectorizer(stop_words=stopwords.words('english'))
X = vectorizer.fit_transform(hotel['Review'])
word_count = pd.DataFrame(X.sum(axis=0), columns=vectorizer.get_feature_names_out()).T.sort_values(0, ascending=False)
word_count.columns = ['count']

plt.figure(figsize=(12, 6))
sns.barplot(x='count', y=word_count.index[:10], data=word_count[:10], palette='viridis')
plt.title('Top 10 Most Frequent Words')
plt.xlabel('Word Count')
plt.ylabel('Words')
plt.show()

# %%
sns.countplot(x='Rating', data=hotel)
plt.title('Distribution of Ratings')
plt.show()

# %%
hotel['Review_Length'] = hotel['Review'].apply(len)
sns.histplot(hotel['Review_Length'], bins=30, kde=True)
plt.title('Distribution of Review Lengths')
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.show()

# %%
max_seq_len = hotel['Review_Length'].max()

# %%
sns.pairplot(hotel, vars=['Rating', 'Review_Length'], hue='Rating', palette='viridis')
plt.suptitle('Pairplot of Ratings and Review Lengths', y=1.02)
plt.show()
# Out:
# C:\Users\sailo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Sentiment Analysis - Polarity Scores

# %%
sid = SentimentIntensityAnalyzer()
def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
hotel['Polarity_Scores'] = hotel['cleaned_reviews'].apply(lambda review: sid.polarity_scores(review)['compound'])

# %%
hotel.head(15)
# Out:
#     Unnamed: 0                                             Review  Rating  \
# 0            0  nice hotel expensive parking got good deal sta...       4
# 1            1  ok nothing special charge diamond member hilto...       2
# 2            2  nice rooms not 4* experience hotel monaco seat...       3
# 3            3  unique, great stay, wonderful time hotel monac...       5
# 4            4  great stay great stay, went seahawk game aweso...       5
# 5            5  love monaco staff husband stayed hotel crazy w...       5
# 6            6  cozy stay rainy city, husband spent 7 nights m...       5
# 7            7  excellent staff, housekeeping quality hotel ch...       4
# 8            8  hotel stayed hotel monaco cruise, rooms genero...       5
# 9            9  excellent stayed hotel monaco past w/e delight...       5
# 10          10  poor value stayed monaco seattle july, nice ho...       2
# 11          11  nice value seattle stayed 4 nights late 2007. ...       4
# 12          12  nice hotel good location hotel kimpton design ...       4
# 13          13  nice hotel not nice staff hotel lovely staff q...       3
# 14          14  great hotel night quick business trip, loved l...       4
#
#                                       cleaned_reviews  Review_Length  \
# 0   nice expensive parking good deal anniversary a...            593
# 1   ok special charge diamond member hilton decide...           1689
# 2   nice not 4 experience monaco seattle good not ...           1427
# 3   unique great wonderful monaco location excelle...            600
# 4   great great seahawk game awesome downfall view...           1281
# 5   love monaco husband crazy weekend attend memor...           1002
# 6   cozy rainy city husband spend 7 monaco early j...            748
# 7   excellent housekeeping quality chock feel home...            597
# 8   monaco cruise generous decorate uniquely remod...            419
# 9   excellent monaco past delight reception friend...            271
# 10  poor value monaco seattle july nice price 100 ...            333
# 11  nice value seattle 4 late 2007 comparable hilt...            364
# 12  nice good location kimpton design whimsical vi...            569
# 13  nice not nice lovely rude bellhop desk clerk w...            417
# 14  great quick business trip love little touch li...            202
#
#     Polarity_Scores
# 0            0.9747
# 1            0.9879
# 2            0.9924
# 3            0.9918
# 4            0.9864
# 5            0.9824
# 6            0.9924
# 7            0.9628
# 8            0.9618
# 9            0.9756
# 10           0.7979
# 11           0.9496
# 12           0.9861
# 13           0.8445
# 14           0.9624

# %%
hotel[hotel['Rating'] < 3].iloc[0,1:3]
# Out:
# Review    ok nothing special charge diamond member hilto...
# Rating                                                    2
# Name: 1, dtype: object

# %%
all_text = ' '.join(hotel['Review'])
wordcloud = WordCloud(max_words=500, width=800, height=400, random_state=42, max_font_size=110).generate(all_text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Word Cloud of Text')
plt.show()

# %%
all_text = ' '.join(hotel['cleaned_reviews'])
wordcloud = WordCloud(max_words=500, width=800, height=400, random_state=42, max_font_size=110).generate(all_text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Word Cloud of Cleaned Text')
plt.show()

# %%
hotel['Polarity_Scores'].max()
# Out:
# 0.9999

# %%
hotel['Polarity_Scores'].min()
# Out:
# -0.9967

# %%
def sentiment(label):
    if label < 0:
        return "Negative"
    elif label >= 0:
        return "Positive"

# %%
hotel['Sentiment'] = hotel['Polarity_Scores'].apply(sentiment)

# %%
hotel.head()
# Out:
#    Unnamed: 0                                             Review  Rating  \
# 0           0  nice hotel expensive parking got good deal sta...       4
# 1           1  ok nothing special charge diamond member hilto...       2
# 2           2  nice rooms not 4* experience hotel monaco seat...       3
# 3           3  unique, great stay, wonderful time hotel monac...       5
# 4           4  great stay great stay, went seahawk game aweso...       5
#
#                                      cleaned_reviews  Review_Length  \
# 0  nice expensive parking good deal anniversary a...            593
# 1  ok special charge diamond member hilton decide...           1689
# 2  nice not 4 experience monaco seattle good not ...           1427
# 3  unique great wonderful monaco location excelle...            600
# 4  great great seahawk game awesome downfall view...           1281
#
#    Polarity_Scores Sentiment
# 0           0.9747  Positive
# 1           0.9879  Positive
# 2           0.9924  Positive
# 3           0.9918  Positive
# 4           0.9864  Positive

# %%
hotel.drop(columns=['Unnamed: 0', 'Review', 'Review_Length'], inplace=True)

# %%
hotel.head()
# Out:
#    Rating                                    cleaned_reviews  Polarity_Scores  \
# 0       4  nice expensive parking good deal anniversary a...           0.9747
# 1       2  ok special charge diamond member hilton decide...           0.9879
# 2       3  nice not 4 experience monaco seattle good not ...           0.9924
# 3       5  unique great wonderful monaco location excelle...           0.9918
# 4       5  great great seahawk game awesome downfall view...           0.9864
#
#   Sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
hotel['Rating'][hotel['Polarity_Scores'] > 0].value_counts()
# Out:
# Rating
# 5    9006
# 4    5972
# 3    2016
# 2    1321
# 1     640
# Name: count, dtype: int64

# %%
hotel['Rating'][hotel['Polarity_Scores'] < 0].value_counts()
# Out:
# Rating
# 1    778
# 2    470
# 3    165
# 4     66
# 5     46
# Name: count, dtype: int64

# %%
pos_revs = hotel[hotel.Sentiment == 'Positive']
pos_revs = pos_revs.sort_values(['Polarity_Scores'], ascending=False)
pos_revs.head()
# Out:
#        Rating                                    cleaned_reviews  \
# 18917       5  ocean blue excellent boyfriend mid20 ocean blu...
# 2967        4  bravo bavaro knew not fivestar incredibly reas...
# 17777       5  fantastic return trip firstly apology length r...
# 14116       5  not wait till year 2nd 16th 2008we lofts week ...
# 14183       4  awesomebeautiful vacation little boonie gran m...
#
#        Polarity_Scores Sentiment
# 18917           0.9999  Positive
# 2967            0.9998  Positive
# 17777           0.9998  Positive
# 14116           0.9998  Positive
# 14183           0.9998  Positive

# %%
text = ' '.join([word for word in pos_revs['cleaned_reviews']])
plt.figure(figsize=(20,15), facecolor='None')
wordcloud = WordCloud(max_words=500,width=1600,height=800).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Most frequent words in positive reviews')
plt.show()

# %%
neg_revs = hotel[hotel.Sentiment == 'Negative']
neg_revs = neg_revs.sort_values(['Polarity_Scores'], ascending=False)
neg_revs.head()

text = ' '.join([word for word in neg_revs['cleaned_reviews']])
plt.figure(figsize=(20,15), facecolor='None')
wordcloud = WordCloud(max_words=500,width=1600,height=800).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Most frequent words in negative reviews')
plt.show()

# %% [markdown]
# ## Vectorization

# %%
X = hotel['cleaned_reviews']
y = hotel['Sentiment']

vectorizer = TfidfVectorizer()

X_vector = vectorizer.fit_transform(X)

oversample = RandomOverSampler(sampling_strategy='minority')
X_over, y_over = oversample.fit_resample(X_vector, y)
undersample = RandomUnderSampler(sampling_strategy='majority')
X_combined, y_combined = undersample.fit_resample(X_over, y_over)

X_train, X_test, y_train, y_test = train_test_split(X_combined, y_combined, test_size=0.3, random_state=12)

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y)
one_hot_labels = to_categorical(encoded_labels) 

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(hotel['cleaned_reviews'].tolist())
sequences = tokenizer.texts_to_sequences(hotel['cleaned_reviews'].tolist())

# Padding sequences to ensure uniform length
max_sequence_length = 100
sequences_padded = pad_sequences(sequences, maxlen=max_sequence_length)

# Define model architecture
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=max_sequence_length))
model.add(LSTM(units=100, return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(units=150))
model.add(Dense(units=32, activation='relu')) 
model.add(Dense(units=2, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(np.array(sequences_padded), one_hot_labels, epochs=4, batch_size=64, validation_split=0.2)

# Evaluate the model
loss, lstm_accuracy = model.evaluate(np.array(sequences_padded), one_hot_labels)
print(f'Test Accuracy: {lstm_accuracy}')
# Out:
# Epoch 1/4
# 257/257 [==============================] - 123s 434ms/step - loss: 0.2066 - accuracy: 0.9270 - val_loss: 0.1412 - val_accuracy: 0.9414
# Epoch 2/4
# 257/257 [==============================] - 100s 388ms/step - loss: 0.1040 - accuracy: 0.9621 - val_loss: 0.1527 - val_accuracy: 0.9414
# Epoch 3/4
# 257/257 [==============================] - 90s 348ms/step - loss: 0.0515 - accuracy: 0.9843 - val_loss: 0.2354 - val_accuracy: 0.9422
# Epoch 4/4
# 257/257 [==============================] - 86s 335ms/step - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.2388 - val_accuracy: 0.9432
# 641/641 [==============================] - 30s 47ms/step - loss: 0.0548 - accuracy: 0.9871
# Test Accuracy: 0.9870675206184387

# %%
new_sequence = tokenizer.texts_to_sequences(["Hotel was expensive but really bad"])
new_sequence_padded = pad_sequences(new_sequence, maxlen=max_sequence_length)

# Make predictions
predicted_probabilities = model.predict(new_sequence_padded)

# Convert probabilities to class labels
predicted_labels = np.argmax(predicted_probabilities, axis=1)

# Decode class labels
predicted_classes = label_encoder.inverse_transform(predicted_labels)

print("Predicted class:", predicted_classes)
print("Predicted probabilities:", predicted_probabilities)
# Out:
# 1/1 [==============================] - 1s 750ms/step
# Predicted class: ['Negative']
# Predicted probabilities: [[0.93822795 0.06177202]]

# %%
new_sequence = tokenizer.texts_to_sequences(["Hotel was expensive but really good"])
new_sequence_padded = pad_sequences(new_sequence, maxlen=max_sequence_length)

# Make predictions
predicted_probabilities = model.predict(new_sequence_padded)

# Convert probabilities to class labels
predicted_labels = np.argmax(predicted_probabilities, axis=1)

# Decode class labels
predicted_classes = label_encoder.inverse_transform(predicted_labels)

print("Predicted class:", predicted_classes)
print("Predicted probabilities:", predicted_probabilities)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Predicted class: ['Negative']
# Predicted probabilities: [[0.8496902  0.15030982]]

# %%
model.save("final_lstm_model.h5")
# Out:
# C:\Users\sailo\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pickle

# %%
with open('tokenizer.pkl', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('label_encoder.pkl', 'wb') as handle:
    pickle.dump(label_encoder, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
logreg_model = LogisticRegression(random_state=42)
logreg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
predictions = logreg_model.predict(X_test)

# %%
logreg_model.score(X_test , y_test)
# Out:
# 0.9586994727592267

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.99      0.96      5661
#     Positive       0.99      0.93      0.96      5719
#
#     accuracy                           0.96     11380
#    macro avg       0.96      0.96      0.96     11380
# weighted avg       0.96      0.96      0.96     11380

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[5615,   46],
#        [ 424, 5295]], dtype=int64)

# %%
lg_ac = accuracy_score(y_test, predictions)

# %% [markdown]
# ## SVC

# %%
clf_svm = SVC(kernel='linear', random_state=42)

clf_svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
clf_svm.score(X_test , y_test)
# Out:
# 0.9785588752196837

# %%
predictions = clf_svm.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.96      1.00      0.98      5661
#     Positive       1.00      0.96      0.98      5719
#
#     accuracy                           0.98     11380
#    macro avg       0.98      0.98      0.98     11380
# weighted avg       0.98      0.98      0.98     11380

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[5653,    8],
#        [ 236, 5483]], dtype=int64)

# %%
sv_ac = accuracy_score(y_test, predictions)

# %%
clf_svm.predict(vectorizer.transform(["Hotel is bad, but people are very good and service is good"]))
# Out:
# array(['Positive'], dtype=object)

# %% [markdown]
# ## Random Forest

# %%
clf_rf = RandomForestClassifier(random_state=42, max_depth=10)

# %%
clf_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
rf_score = clf_rf.score(X_test, y_test)
print("Random Forest Classifier Score:", rf_score)
# Out:
# Random Forest Classifier Score: 0.9201230228471001

# %%
predictions_rf = clf_rf.predict(X_test)

# %%
print(classification_report(y_test, predictions_rf))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.96      0.92      5661
#     Positive       0.95      0.88      0.92      5719
#
#     accuracy                           0.92     11380
#    macro avg       0.92      0.92      0.92     11380
# weighted avg       0.92      0.92      0.92     11380

# %%
print(confusion_matrix(y_test, predictions_rf))
# Out:
# [[5416  245]
#  [ 664 5055]]

# %%
rf_ac=accuracy_score(y_test, predictions_rf)
rf_ac
# Out:
# 0.9201230228471001

# %%
rf_cv_scores = cross_val_score(clf_rf, X_train, y_train, cv=5)

# %% [markdown]
# ## Gradient Boost

# %%
clf_gb = GradientBoostingClassifier(random_state=42)

# %%
clf_gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
gb_score = clf_gb.score(X_test, y_test)
print("Gradient Boosting Classifier Score:", gb_score)
# Out:
# Gradient Boosting Classifier Score: 0.9169595782073814

# %%
predictions_gb = clf_gb.predict(X_test)

# %%
print(classification_report(y_test, predictions_gb))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.95      0.92      5661
#     Positive       0.95      0.88      0.91      5719
#
#     accuracy                           0.92     11380
#    macro avg       0.92      0.92      0.92     11380
# weighted avg       0.92      0.92      0.92     11380

# %%
print(confusion_matrix(y_test, predictions_gb))
# Out:
# [[5396  265]
#  [ 680 5039]]

# %%
gb_ac=accuracy_score(y_test, predictions_gb)
gb_ac
# Out:
# 0.9169595782073814

# %% [markdown]
# ## Adaboost

# %%
adaboost_clf = AdaBoostClassifier(
    n_estimators=50,
    learning_rate=1.0,
    algorithm='SAMME.R')

# %%
adaboost_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
ab_score = adaboost_clf.score(X_test, y_test)
print("Adaboost Classifier Score:", ab_score)
# Out:
# Adaboost Classifier Score: 0.882688927943761

# %%
adaboost_pred = adaboost_clf.predict(X_test)

# %%
print(classification_report(y_test, adaboost_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.89      0.88      5661
#     Positive       0.89      0.88      0.88      5719
#
#     accuracy                           0.88     11380
#    macro avg       0.88      0.88      0.88     11380
# weighted avg       0.88      0.88      0.88     11380

# %%
print(confusion_matrix(y_test, adaboost_pred))
# Out:
# [[5016  645]
#  [ 690 5029]]

# %%
ab_ac=accuracy_score(y_test, adaboost_pred)
ab_ac
# Out:
# 0.882688927943761

# %% [markdown]
# ## CNN

# %%
max_words = 2500
embed_dim = 100

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(hotel.cleaned_reviews.values)
word_index = tokenizer.word_index
X_cnn = tokenizer.texts_to_sequences(hotel.cleaned_reviews.values)

# %%
X_cnn = pad_sequences(X_cnn, maxlen=max_seq_len)
y_cnn = pd.get_dummies(hotel['Sentiment']).values

X_cnn_train, X_cnn_test, y_cnn_train, y_cnn_test = train_test_split(X_cnn, y_cnn, test_size=0.2, random_state=42)

# %%
X_cnn_train.shape
# Out:
# (16392, 13501)

# %%
y_cnn_train.shape
# Out:
# (16392, 2)

# %%
# cnn = Sequential()
# cnn.add(Embedding(max_words, embed_dim, input_length=X_cnn_train.shape[1]))
# cnn.add(Conv1D(filters=128, kernel_size=5, activation='relu'))
# cnn.add(GlobalMaxPool1D())
# cnn.add(Dense(64, activation='relu'))
# cnn.add(Dense(2, activation='softmax'))
# cnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics='accuracy')

# history = cnn.fit(X_cnn_train, y_cnn_train, epochs=5, batch_size=64, validation_split=0.1)

# %%
#cnn.save("trained_cnn_model.h5")

# %%
cnn = load_model("trained_cnn_model.h5")

# %%
cnn_ac = cnn.evaluate(X_cnn_test, y_cnn_test)
print(f'Loss: {cnn_ac[0]:.3f}\nAccuracy: {cnn_ac[1]:.3f}')
# Out:
# 129/129 [==============================] - 47s 360ms/step - loss: 0.2623 - accuracy: 0.9475
# Loss: 0.262
# Accuracy: 0.948

# %% [markdown]
# ## Naive Bayes

# %%
clf_nb = MultinomialNB()
clf_nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nb_score = clf_nb.score(X_test, y_test)
print("Naive Bayes Classifier Score:", nb_score)
# Out:
# Naive Bayes Classifier Score: 0.9313708260105448

# %%
predictions_nb = clf_nb.predict(X_test)

# %%
print(classification_report(y_test, predictions_nb))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.96      0.93      5661
#     Positive       0.96      0.90      0.93      5719
#
#     accuracy                           0.93     11380
#    macro avg       0.93      0.93      0.93     11380
# weighted avg       0.93      0.93      0.93     11380

# %%
print(confusion_matrix(y_test, predictions_nb))
# Out:
# [[5460  201]
#  [ 580 5139]]

# %%
nb_ac=accuracy_score(y_test, predictions_nb)
nb_ac
# Out:
# 0.9313708260105448

# %%
nb_cv_scores = cross_val_score(clf_nb, X_train, y_train, cv=5)

# %% [markdown]
# ## Decision Tree - Gini

# %%
cart_gini = DecisionTreeClassifier(criterion='gini', max_depth=39)

# %%
cart_gini_cv_scores = cross_val_score(cart_gini, X_train, y_train, cv=5)

# %%
cart_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=39)

# %%
pred_gini = cart_gini.predict(X_test)
cartg_ac = accuracy_score(y_test, pred_gini)
print("Decision Tree Classifier Accuracy:", cartg_ac)
# Out:
# Decision Tree Classifier Accuracy: 0.9516695957820738

# %%
print(classification_report(y_test, pred_gini))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.91      1.00      0.95      5661
#     Positive       1.00      0.90      0.95      5719
#
#     accuracy                           0.95     11380
#    macro avg       0.96      0.95      0.95     11380
# weighted avg       0.96      0.95      0.95     11380

# %%
print("Cross-Validation Scores:", cart_gini_cv_scores)
print("Mean Cross-Validation Score:", np.mean(cart_gini_cv_scores))
# Out:
# Cross-Validation Scores: [0.94690265 0.94916212 0.94708098 0.95178908 0.9440678 ]
# Mean Cross-Validation Score: 0.9478005248673738

# %% [markdown]
# ## Decision Tree - Entropy

# %%
cart_ent = DecisionTreeClassifier(criterion='entropy', max_depth=39)

# %%
cart_ent_cv_scores = cross_val_score(cart_ent, X_train, y_train, cv=5)

# %%
cart_ent.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=39)

# %%
pred_ent = cart_ent.predict(X_test)
carte_ac = accuracy_score(y_test, pred_ent)
print("Decision Tree Classifier Accuracy:", carte_ac)
# Out:
# Decision Tree Classifier Accuracy: 0.9563268892794377

# %%
print(classification_report(y_test, pred_ent))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.92      1.00      0.96      5661
#     Positive       1.00      0.91      0.95      5719
#
#     accuracy                           0.96     11380
#    macro avg       0.96      0.96      0.96     11380
# weighted avg       0.96      0.96      0.96     11380

# %%
print("Cross-Validation Scores:", cart_ent_cv_scores)
print("Mean Cross-Validation Score:", np.mean(cart_ent_cv_scores))
# Out:
# Cross-Validation Scores: [0.9542459  0.95066842 0.95423729 0.95084746 0.95160075]
# Mean Cross-Validation Score: 0.9523199655620056

# %% [markdown]
# ## KNN

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train, y_train)

predictions_knn = knn_classifier.predict(X_test)

knn_ac = accuracy_score(y_test, predictions_knn)
print(f"Accuracy: {knn_ac}")

classification_rep = classification_report(y_test, predictions_knn)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.922231985940246
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative       0.87      1.00      0.93      5661
#     Positive       1.00      0.85      0.92      5719
#
#     accuracy                           0.92     11380
#    macro avg       0.93      0.92      0.92     11380
# weighted avg       0.93      0.92      0.92     11380

# %%
print(confusion_matrix(y_test, predictions_nb))
# Out:
# [[5460  201]
#  [ 580 5139]]

# %%
modelEvaldf = pd.DataFrame(columns=['Model', 'ACCURACY'])
modelEvaldf.loc[len(modelEvaldf.index)] = ['Logistic Regression', lg_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['SVC', sv_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Random Forest classifier', rf_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Gradient Boost classifier', gb_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['AdaBoost classifier', ab_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['CNN', round(cnn_ac[1], 3)]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Naive Bayes classifier', nb_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Random Forest classifier K-Fold', np.mean(rf_cv_scores)]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Naive Bayes classifier K-Fold', np.mean(nb_cv_scores)]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Decision Tree Gini', cartg_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Decision Tree Gini K-Fold', np.mean(cart_gini_cv_scores)]
modelEvaldf.loc[len(modelEvaldf.index)] = ['LSTM', lstm_accuracy]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Decision Tree Entropy', carte_ac]
modelEvaldf.loc[len(modelEvaldf.index)] = ['Decision Tree Entropy K-Fold', np.mean(cart_ent_cv_scores)]
modelEvaldf.loc[len(modelEvaldf.index)] = ['KNN', knn_ac]

# %%
modelEvaldf
# Out:
#                               Model  ACCURACY
# 0               Logistic Regression  0.958699
# 1                               SVC  0.978559
# 2          Random Forest classifier  0.920123
# 3         Gradient Boost classifier  0.916960
# 4               AdaBoost classifier  0.882689
# 5                               CNN  0.948000
# 6            Naive Bayes classifier  0.931371
# 7   Random Forest classifier K-Fold  0.912775
# 8     Naive Bayes classifier K-Fold  0.929874
# 9                Decision Tree Gini  0.951670
# 10        Decision Tree Gini K-Fold  0.947801
# 11                             LSTM  0.987068
# 12            Decision Tree Entropy  0.956327
# 13     Decision Tree Entropy K-Fold  0.952320
# 14                              KNN  0.922232
